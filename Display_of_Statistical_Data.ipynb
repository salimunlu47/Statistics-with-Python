# %% [markdown]
# # Functional and Object-Oriented Approaches to Plotting

# %%
# Import the required packages, with their conventional names
import matplotlib.pyplot as plt
import numpy as np
# Generate the data
x = np.arange(0, 15, 0.1)
y = np.sin(x)
# Generate the plot
plt.plot(x, y)
# Display it on the screen
plt.show()

# %%
# Generate the plot
fig = plt.figure() # Generate the figure
ax = fig.add_subplot(111) # Add an axis to that figure
ax.plot(x,y) # Add a plot to that axis

# %%
from pylab import *
x = arange(0, 15, 0.1)
y = sin(x)
plot(x, y)
show()

# %% [markdown]
# The following lines of code produce a figure with two plots above each other, and clearly indicate which plot goes into which axis:

# %%
# Import the required packages
import matplotlib.pyplot as plt
import numpy as np
# Generate the data
x = np.arange(0, 15, 0.1)
y = np.sin(x)
z = np.cos(x)
# Generate the figure and the axes
fig, axs = plt.subplots(nrows=2, ncols=1)
# On the first axis, plot the sine and label the ordinate
axs[0].plot(x,y)
axs[0].set_ylabel('Sine')
# On the second axis, plot the cosine
axs[1].plot(x,z)
axs[1].set_ylabel('Cosine')
# Display the resulting plot
plt.show()

# %% [markdown]
# ## Scatter Plots

# %%
# Import standard packages
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import scipy.stats as stats
import seaborn as sns
# Generate the data
x = np.random.randn(500)
# Plot-command start ---------------------
plt.plot(x, '.')
# Plot-command end -----------------------
# Show plot
plt.show()

# %% [markdown]
# ## Histograms

# %%
plt.hist(x, bins=25)
# Out:
# (array([ 2.,  3.,  5.,  5., 10., 15., 24., 32., 40., 51., 51., 55., 58.,
#         38., 33., 20., 19., 16., 13.,  4.,  1.,  3.,  1.,  0.,  1.]),
#  array([-3.18566549, -2.90858798, -2.63151048, -2.35443298, -2.07735547,
#         -1.80027797, -1.52320047, -1.24612296, -0.96904546, -0.69196796,
#         -0.41489045, -0.13781295,  0.13926456,  0.41634206,  0.69341956,
#          0.97049707,  1.24757457,  1.52465207,  1.80172958,  2.07880708,
#          2.35588459,  2.63296209,  2.91003959,  3.1871171 ,  3.4641946 ,
#          3.7412721 ]),
#  <a list of 25 Patch objects>)

# %% [markdown]
# ## Univariate Data

# %%
# Import standard packages
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import scipy.stats as stats
import seaborn as sns

# %%
# Generate the data
x = np.random.randn(500)

# %%
# Plot-command start ---------------------
plt.plot(x, '.')
# Plot-command end -----------------------
# Show plot
plt.show()

# %% [markdown]
# ### Scatter Plots

# %%
plt.plot(x, '.')

# %%
plt.scatter(range(0,500),x)

# %% [markdown]
# ### Histograms

# %%
plt.hist(x, bins=25)
# Out:
# (array([ 5.,  5., 12., 16., 17., 20., 29., 42., 69., 50., 43., 51., 39.,
#         29., 24., 16., 16.,  5.,  5.,  3.,  2.,  1.,  0.,  0.,  1.]),
#  array([-2.57249597, -2.30751888, -2.04254179, -1.77756469, -1.5125876 ,
#         -1.24761051, -0.98263342, -0.71765633, -0.45267924, -0.18770214,
#          0.07727495,  0.34225204,  0.60722913,  0.87220622,  1.13718332,
#          1.40216041,  1.6671375 ,  1.93211459,  2.19709168,  2.46206878,
#          2.72704587,  2.99202296,  3.25700005,  3.52197714,  3.78695424,
#          4.05193133]),
#  <a list of 25 Patch objects>)

# %% [markdown]
# ### Kernel-Density-Estimation (KDE) Plots

# %%
x = [-2.1, -1.3, -0.4, 1.9, 5.1, 6.2]

# %%
sns.kdeplot(x)

# %%
plt.hist(x)
# Out:
# (array([2., 0., 1., 0., 1., 0., 0., 0., 1., 1.]),
#  array([-2.1 , -1.27, -0.44,  0.39,  1.22,  2.05,  2.88,  3.71,  4.54,
#          5.37,  6.2 ]),
#  <a list of 10 Patch objects>)

# %% [markdown]
# ### Cumulative Frequencies

# %%
plt.plot(stats.cumfreq(x,100)[0])

# %% [markdown]
# ### Error-Bars

# %%
index = np.arange(5)
y = index**2
errorBar = index/2 # just for demonstration
plt.errorbar(index,y, yerr=errorBar, fmt='o', capsize=5, capthick=3)
# Out:
# <ErrorbarContainer object of 3 artists>

# %% [markdown]
# ### Box Plots

# %%
plt.boxplot(x, sym='*')
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x147e0206fc8>,
#   <matplotlib.lines.Line2D at 0x147e020b9c8>],
#  'caps': [<matplotlib.lines.Line2D at 0x147e020bac8>,
#   <matplotlib.lines.Line2D at 0x147e020f948>],
#  'boxes': [<matplotlib.lines.Line2D at 0x147e0206888>],
#  'medians': [<matplotlib.lines.Line2D at 0x147e020ffc8>],
#  'fliers': [<matplotlib.lines.Line2D at 0x147e0215908>],
#  'means': []}
